# %% [markdown]
# Should study [open-context-jupyter/Open Context Measurements.ipynb at master · ekansa/open-context-jupyter](https://github.com/ekansa/open-context-jupyter/blob/master/notebooks/Open%20Context%20Measurements.ipynb)
#
# May make use of [digitalbazaar/pyld: JSON-LD processor written in Python](https://github.com/digitalbazaar/pyld)

# %%
from itertools import islice
import json
from urllib.parse import urljoin
from urllib.parse import urlencode, quote_plus

import requests
from requests.packages.urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

from pyld import jsonld

import pandas as pd
import numpy as np
from pandas import DataFrame, Series, Index

# %%
def filter_none(d):
    return dict([(k,v) for (k,v) in d.items() if v is not None])


class OpenContextAPI(object):
    def __init__(self, api_url="https://opencontext.org/"):
        self.api_url = api_url
        self.session = requests.Session()
        retries = Retry(total=5,
                backoff_factor=0.3,
                status_forcelist=[ 500, 502, 503, 504 ])
        self.session.mount(self.api_url, HTTPAdapter(max_retries=retries))
        
    def _pager(self, url):
        while url:
            r = self.session.get(url)
            if r.status_code == 200:
                features = r.json().get('features', [])
                yield from features
            else:
                # to do: figure what to do when non-200 status code
                pass
            url = r.json().get('next-json', None)
        
        
    def projects_search(self, start=None, stop=None, rows=None):

        kw = filter_none({
            'start': start,
            'stop': stop,
            'rows': rows
        })
        
        url = urljoin(self.api_url, "projects-search.json") + "?" + urlencode(kw, quote_via=quote_plus)
        yield from self._pager(url)
        
                
    def project(self, project_id):
        
        url = urljoin(self.api_url, "projects/{}.json".format(project_id))
        r = self.session.get(url)
        if r.status_code == 200:
            return r.json()
        
    def subjects_search(self, project_id):
        """
        start with https://opencontext.org/subjects-search.json/?proj=12-presidio-of-san-francisco
        
        more complex possibilties:
        https://opencontext.org/subjects-search.json/?proj=12-presidio-of-san-francisco#10/37.8001/-122.4559/20/any/Google-Satellite.json
        """
        url = urljoin(self.api_url, "subjects-search.json/") + "?proj={}".format(project_id)
        print (url)
        yield from self._pager(url)

# %%
oc = OpenContextAPI()

# %%
features = oc.projects_search(rows=1000)

projects_df = DataFrame(list(islice(features,None)))
projects_df
# Out:
#              category                                           geometry  \
# 0   oc-api:geo-record  {'id': '#geo-rec-geom-1-of-109', 'type': 'Poin...
# 1   oc-api:geo-record  {'id': '#geo-rec-geom-2-of-109', 'type': 'Poin...
# 2   oc-api:geo-record  {'id': '#geo-rec-geom-3-of-109', 'type': 'Poin...
# 3   oc-api:geo-record  {'id': '#geo-rec-geom-4-of-109', 'type': 'Poin...
# 4   oc-api:geo-record  {'id': '#geo-rec-geom-5-of-109', 'type': 'Poin...
# 5   oc-api:geo-record  {'id': '#geo-rec-geom-6-of-109', 'type': 'Poin...
# 6   oc-api:geo-record  {'id': '#geo-rec-geom-7-of-109', 'type': 'Poin...
# 7   oc-api:geo-record  {'id': '#geo-rec-geom-8-of-109', 'type': 'Poin...
# 8   oc-api:geo-record  {'id': '#geo-rec-geom-10-of-109', 'type': 'Poi...
# 9   oc-api:geo-record  {'id': '#geo-rec-geom-11-of-109', 'type': 'Poi...
# 10  oc-api:geo-record  {'id': '#geo-rec-geom-12-of-109', 'type': 'Poi...
# 11  oc-api:geo-record  {'id': '#geo-rec-geom-13-of-109', 'type': 'Poi...
# 12  oc-api:geo-record  {'id': '#geo-rec-geom-15-of-109', 'type': 'Poi...
# 13  oc-api:geo-record  {'id': '#geo-rec-geom-17-of-109', 'type': 'Poi...
# 14  oc-api:geo-record  {'id': '#geo-rec-geom-18-of-109', 'type': 'Poi...
# 15  oc-api:geo-record  {'id': '#geo-rec-geom-19-of-109', 'type': 'Poi...
# 16  oc-api:geo-record  {'id': '#geo-rec-geom-21-of-109', 'type': 'Poi...
# 17  oc-api:geo-record  {'id': '#geo-rec-geom-22-of-109', 'type': 'Poi...
# 18  oc-api:geo-record  {'id': '#geo-rec-geom-24-of-109', 'type': 'Poi...
# 19  oc-api:geo-record  {'id': '#geo-rec-geom-25-of-109', 'type': 'Poi...
# 20  oc-api:geo-record  {'id': '#geo-rec-geom-26-of-109', 'type': 'Poi...
# 21  oc-api:geo-record  {'id': '#geo-rec-geom-27-of-109', 'type': 'Poi...
# 22  oc-api:geo-record  {'id': '#geo-rec-geom-29-of-109', 'type': 'Poi...
# 23  oc-api:geo-record  {'id': '#geo-rec-geom-31-of-109', 'type': 'Poi...
# 24  oc-api:geo-record  {'id': '#geo-rec-geom-32-of-109', 'type': 'Poi...
# 25  oc-api:geo-record  {'id': '#geo-rec-geom-33-of-109', 'type': 'Poi...
# 26  oc-api:geo-record  {'id': '#geo-rec-geom-34-of-109', 'type': 'Poi...
# 27  oc-api:geo-record  {'id': '#geo-rec-geom-35-of-109', 'type': 'Poi...
# 28  oc-api:geo-record  {'id': '#geo-rec-geom-36-of-109', 'type': 'Poi...
# 29  oc-api:geo-record  {'id': '#geo-rec-geom-37-of-109', 'type': 'Poi...
# ..                ...                                                ...
# 48  oc-api:geo-record  {'id': '#geo-rec-geom-61-of-109', 'type': 'Poi...
# 49  oc-api:geo-record  {'id': '#geo-rec-geom-62-of-109', 'type': 'Poi...
# 50  oc-api:geo-record  {'id': '#geo-rec-geom-63-of-109', 'type': 'Poi...
# 51  oc-api:geo-record  {'id': '#geo-rec-geom-64-of-109', 'type': 'Poi...
# 52  oc-api:geo-record  {'id': '#geo-rec-geom-65-of-109', 'type': 'Poi...
# 53  oc-api:geo-record  {'id': '#geo-rec-geom-66-of-109', 'type': 'Poi...
# 54  oc-api:geo-record  {'id': '#geo-rec-geom-68-of-109', 'type': 'Poi...
# 55  oc-api:geo-record  {'id': '#geo-rec-geom-69-of-109', 'type': 'Poi...
# 56  oc-api:geo-record  {'id': '#geo-rec-geom-70-of-109', 'type': 'Poi...
# 57  oc-api:geo-record  {'id': '#geo-rec-geom-71-of-109', 'type': 'Poi...
# 58  oc-api:geo-record  {'id': '#geo-rec-geom-73-of-109', 'type': 'Poi...
# 59  oc-api:geo-record  {'id': '#geo-rec-geom-75-of-109', 'type': 'Poi...
# 60  oc-api:geo-record  {'id': '#geo-rec-geom-80-of-109', 'type': 'Poi...
# 61  oc-api:geo-record  {'id': '#geo-rec-geom-83-of-109', 'type': 'Poi...
# 62  oc-api:geo-record  {'id': '#geo-rec-geom-84-of-109', 'type': 'Poi...
# 63  oc-api:geo-record  {'id': '#geo-rec-geom-85-of-109', 'type': 'Poi...
# 64  oc-api:geo-record  {'id': '#geo-rec-geom-86-of-109', 'type': 'Poi...
# 65  oc-api:geo-record  {'id': '#geo-rec-geom-88-of-109', 'type': 'Poi...
# 66  oc-api:geo-record  {'id': '#geo-rec-geom-89-of-109', 'type': 'Poi...
# 67  oc-api:geo-record  {'id': '#geo-rec-geom-90-of-109', 'type': 'Poi...
# 68  oc-api:geo-record  {'id': '#geo-rec-geom-91-of-109', 'type': 'Poi...
# 69  oc-api:geo-record  {'id': '#geo-rec-geom-92-of-109', 'type': 'Poi...
# 70  oc-api:geo-record  {'id': '#geo-rec-geom-93-of-109', 'type': 'Poi...
# 71  oc-api:geo-record  {'id': '#geo-rec-geom-94-of-109', 'type': 'Poi...
# 72  oc-api:geo-record  {'id': '#geo-rec-geom-96-of-109', 'type': 'Poi...
# 73  oc-api:geo-record  {'id': '#geo-rec-geom-97-of-109', 'type': 'Poi...
# 74  oc-api:geo-record  {'id': '#geo-rec-geom-98-of-109', 'type': 'Poi...
# 75  oc-api:geo-record  {'id': '#geo-rec-geom-99-of-109', 'type': 'Poi...
# 76  oc-api:geo-record  {'id': '#geo-rec-geom-100-of-109', 'type': 'Po...
# 77  oc-api:geo-record  {'id': '#geo-rec-geom-106-of-109', 'type': 'Po...
#
#                     id                                              label  \
# 0     #record-1-of-109                                         Kenan Tepe
# 1     #record-2-of-109  Architecture and Urbanism at Seyitömer Höyük, ...
# 2     #record-3-of-109                              Iraq Heritage Program
# 3     #record-4-of-109              ARCE Sphinx Project 1979-1983 Archive
# 4     #record-5-of-109                                        Bade Museum
# 5     #record-6-of-109          Dhiban Excavation and Development Project
# 6     #record-7-of-109                     Zooarchaeology of Öküzini Cave
# 7     #record-8-of-109                                              Murlo
# 8    #record-10-of-109                      Çukuriçi Höyük Zooarchaeology
# 9    #record-11-of-109                             Köşk Höyük Faunal Data
# 10   #record-12-of-109                    Zooarchaeology of Karain Cave B
# 11   #record-13-of-109                          Çatalhöyük Zooarchaeology
# 12   #record-15-of-109                                 Hacksilber Project
# 13   #record-17-of-109                     Petra Great Temple Excavations
# 14   #record-18-of-109  Biometrical Database of European Aurochs and D...
# 15   #record-19-of-109            Erbaba Höyük and Suberde Zooarchaeology
# 16   #record-21-of-109                       Animal remains from Forcello
# 17   #record-22-of-109                            Ilıpınar Zooarchaeology
# 18   #record-24-of-109  Faunal Data from Al-Wu’ayra Fortress, Petra Va...
# 19   #record-25-of-109                        Barçın Höyük Zooarchaeology
# 20   #record-26-of-109                                   Virtual Valdivia
# 21   #record-27-of-109                            Giza Botanical Database
# 22   #record-29-of-109                            Mikt’sqaq Angayuk Finds
# 23   #record-31-of-109            Georgia Archaeological Site File (GASF)
# 24   #record-32-of-109  Northern Mesopotamian Pig Husbandry (Late Neol...
# 25   #record-33-of-109                 Faunal Data from Neolithic Menteşe
# 26   #record-34-of-109                                  Chogha Mish Fauna
# 27   #record-35-of-109  Ceramics, Trade, Provenience and Geology: Cypr...
# 28   #record-36-of-109                          Dove Mountain Groundstone
# 29   #record-37-of-109                               Asian Stoneware Jars
# ..                 ...                                                ...
# 48   #record-61-of-109                                South Carolina SHPO
# 49   #record-62-of-109                       Pınarbaşı 1994: Animal Bones
# 50   #record-63-of-109                          Presidio of San Francisco
# 51   #record-64-of-109                            Pennsylvania Site Files
# 52   #record-65-of-109                                    Ohio Site Files
# 53   #record-66-of-109                          Oracle Bones in East Asia
# 54   #record-68-of-109                Harvard Peabody Mus. Zooarchaeology
# 55   #record-69-of-109                       Traces in the Lost Landscape
# 56   #record-70-of-109                       Kuthodaw Pagoda Inscriptions
# 57   #record-71-of-109  Images Documenting The Ottoman Tiles of the Fa...
# 58   #record-73-of-109  Digital Companion to "A Preliminary Analysis o...
# 59   #record-75-of-109                                  The Gabii Project
# 60   #record-80-of-109              Lake Carlos Beach Site, 1992 and 1996
# 61   #record-83-of-109  Digital Companion to 'Late Nineteenth and Earl...
# 62   #record-84-of-109  Biometry of Iron Age II and Hellenistic Period...
# 63   #record-85-of-109                                Virginia Site Files
# 64   #record-86-of-109                             Historic Fort Snelling
# 65   #record-88-of-109                               Louisiana Site Files
# 66   #record-89-of-109                                 Alabama Site Files
# 67   #record-90-of-109                               Tennessee Site Files
# 68   #record-91-of-109                                      Rough Cilicia
# 69   #record-92-of-109                          North Carolina Site Files
# 70   #record-93-of-109                                Maryland Site Files
# 71   #record-94-of-109                              Hazor: Zooarchaeology
# 72   #record-96-of-109                    San Diego Archaeological Center
# 73   #record-97-of-109              Corneal Ulceration in South East Asia
# 74   #record-98-of-109                           Hayonim: Micromorphology
# 75   #record-99-of-109  Images Documenting Looting in the North Cemete...
# 76  #record-100-of-109                  Geissenklosterle: Micromorphology
# 77  #record-106-of-109                               Excavations at Polis
#
#                                            properties  \
# 0   {'id': '#rec-1-of-109', 'feature-type': 'item ...
# 1   {'id': '#rec-2-of-109', 'feature-type': 'item ...
# 2   {'id': '#rec-3-of-109', 'feature-type': 'item ...
# 3   {'id': '#rec-4-of-109', 'feature-type': 'item ...
# 4   {'id': '#rec-5-of-109', 'feature-type': 'item ...
# 5   {'id': '#rec-6-of-109', 'feature-type': 'item ...
# 6   {'id': '#rec-7-of-109', 'feature-type': 'item ...
# 7   {'id': '#rec-8-of-109', 'feature-type': 'item ...
# 8   {'id': '#rec-10-of-109', 'feature-type': 'item...
# 9   {'id': '#rec-11-of-109', 'feature-type': 'item...
# 10  {'id': '#rec-12-of-109', 'feature-type': 'item...
# 11  {'id': '#rec-13-of-109', 'feature-type': 'item...
# 12  {'id': '#rec-15-of-109', 'feature-type': 'item...
# 13  {'id': '#rec-17-of-109', 'feature-type': 'item...
# 14  {'id': '#rec-18-of-109', 'feature-type': 'item...
# 15  {'id': '#rec-19-of-109', 'feature-type': 'item...
# 16  {'id': '#rec-21-of-109', 'feature-type': 'item...
# 17  {'id': '#rec-22-of-109', 'feature-type': 'item...
# 18  {'id': '#rec-24-of-109', 'feature-type': 'item...
# 19  {'id': '#rec-25-of-109', 'feature-type': 'item...
# 20  {'id': '#rec-26-of-109', 'feature-type': 'item...
# 21  {'id': '#rec-27-of-109', 'feature-type': 'item...
# 22  {'id': '#rec-29-of-109', 'feature-type': 'item...
# 23  {'id': '#rec-31-of-109', 'feature-type': 'item...
# 24  {'id': '#rec-32-of-109', 'feature-type': 'item...
# 25  {'id': '#rec-33-of-109', 'feature-type': 'item...
# 26  {'id': '#rec-34-of-109', 'feature-type': 'item...
# 27  {'id': '#rec-35-of-109', 'feature-type': 'item...
# 28  {'id': '#rec-36-of-109', 'feature-type': 'item...
# 29  {'id': '#rec-37-of-109', 'feature-type': 'item...
# ..                                                ...
# 48  {'id': '#rec-61-of-109', 'feature-type': 'item...
# 49  {'id': '#rec-62-of-109', 'feature-type': 'item...
# 50  {'id': '#rec-63-of-109', 'feature-type': 'item...
# 51  {'id': '#rec-64-of-109', 'feature-type': 'item...
# 52  {'id': '#rec-65-of-109', 'feature-type': 'item...
# 53  {'id': '#rec-66-of-109', 'feature-type': 'item...
# 54  {'id': '#rec-68-of-109', 'feature-type': 'item...
# 55  {'id': '#rec-69-of-109', 'feature-type': 'item...
# 56  {'id': '#rec-70-of-109', 'feature-type': 'item...
# 57  {'id': '#rec-71-of-109', 'feature-type': 'item...
# 58  {'id': '#rec-73-of-109', 'feature-type': 'item...
# 59  {'id': '#rec-75-of-109', 'feature-type': 'item...
# 60  {'id': '#rec-80-of-109', 'feature-type': 'item...
# 61  {'id': '#rec-83-of-109', 'feature-type': 'item...
# 62  {'id': '#rec-84-of-109', 'feature-type': 'item...
# 63  {'id': '#rec-85-of-109', 'feature-type': 'item...
# 64  {'id': '#rec-86-of-109', 'feature-type': 'item...
# 65  {'id': '#rec-88-of-109', 'feature-type': 'item...
# 66  {'id': '#rec-89-of-109', 'feature-type': 'item...
# 67  {'id': '#rec-90-of-109', 'feature-type': 'item...
# 68  {'id': '#rec-91-of-109', 'feature-type': 'item...
# 69  {'id': '#rec-92-of-109', 'feature-type': 'item...
# 70  {'id': '#rec-93-of-109', 'feature-type': 'item...
# 71  {'id': '#rec-94-of-109', 'feature-type': 'item...
# 72  {'id': '#rec-96-of-109', 'feature-type': 'item...
# 73  {'id': '#rec-97-of-109', 'feature-type': 'item...
# 74  {'id': '#rec-98-of-109', 'feature-type': 'item...
# 75  {'id': '#rec-99-of-109', 'feature-type': 'item...
# 76  {'id': '#rec-100-of-109', 'feature-type': 'ite...
# 77  {'id': '#rec-106-of-109', 'feature-type': 'ite...
#
#                                      rdfs:isDefinedBy     type
# 0   http://opencontext.org/projects/3DE4CD9C-259E-...  Feature
# 1   http://opencontext.org/projects/347286db-b6c6-...  Feature
# 2   http://opencontext.org/projects/GHF1PRJ0000000025  Feature
# 3   http://opencontext.org/projects/141e814a-ba2d-...  Feature
# 4   http://opencontext.org/projects/B4345F6A-F926-...  Feature
# 5   http://opencontext.org/projects/01D080DF-2F6B-...  Feature
# 6   http://opencontext.org/projects/8894EEC0-DC96-...  Feature
# 7   http://opencontext.org/projects/DF043419-F23B-...  Feature
# 8   http://opencontext.org/projects/BC90D462-6639-...  Feature
# 9   http://opencontext.org/projects/05F5B702-2967-...  Feature
# 10  http://opencontext.org/projects/731B0670-CE2A-...  Feature
# 11  http://opencontext.org/projects/1B426F7C-99EC-...  Feature
# 12  http://opencontext.org/projects/CF179695-1E6A-...  Feature
# 13  http://opencontext.org/projects/A5DDBEA2-B3C8-...  Feature
# 14  http://opencontext.org/projects/1816A043-92E2-...  Feature
# 15  http://opencontext.org/projects/CDD40C27-62ED-...  Feature
# 16  http://opencontext.org/projects/bdc6cb19-e739-...  Feature
# 17  http://opencontext.org/projects/D297CD29-50CA-...  Feature
# 18  http://opencontext.org/projects/ea62c747-f3ae-...  Feature
# 19  http://opencontext.org/projects/74749949-4FD4-...  Feature
# 20  http://opencontext.org/projects/d3bed915-947d-...  Feature
# 21  http://opencontext.org/projects/10aa84ad-c5de-...  Feature
# 22  http://opencontext.org/projects/CF6E1364-D6EF-...  Feature
# 23  http://opencontext.org/projects/64013C33-4039-...  Feature
# 24  http://opencontext.org/projects/d1c85af4-c870-...  Feature
# 25  http://opencontext.org/projects/42EAD4DB-BAED-...  Feature
# 26  http://opencontext.org/projects/497ADEAD-0C2A-...  Feature
# 27  http://opencontext.org/projects/ABABD13C-A69F-...  Feature
# 28  http://opencontext.org/projects/A3CBADB6-6CD4-...  Feature
# 29  http://opencontext.org/projects/4B16F48E-6F5D-...  Feature
# ..                                                ...      ...
# 48  http://opencontext.org/projects/0EE6A09E-62E5-...  Feature
# 49  http://opencontext.org/projects/TESTPRJ0000000004  Feature
# 50  http://opencontext.org/projects/C5B4F73B-5EF8-...  Feature
# 51  http://opencontext.org/projects/766698E3-2E79-...  Feature
# 52  http://opencontext.org/projects/EDDA846F-7225-...  Feature
# 53  http://opencontext.org/projects/27e90af3-6bf7-...  Feature
# 54  http://opencontext.org/projects/HPeaZooPRJ0000...  Feature
# 55  http://opencontext.org/projects/23696274-1f6d-...  Feature
# 56  http://opencontext.org/projects/b6de18c6-bba8-...  Feature
# 57  http://opencontext.org/projects/2bc1f77d-fe36-...  Feature
# 58  http://opencontext.org/projects/a820af0c-ab4d-...  Feature
# 59  http://opencontext.org/projects/3585b372-8d2d-...  Feature
# 60  http://opencontext.org/projects/MHS1PRJ0000000021  Feature
# 61  http://opencontext.org/projects/8ae150fc-50f1-...  Feature
# 62  http://opencontext.org/projects/646b7034-07b7-...  Feature
# 63  http://opencontext.org/projects/AF0D2F67-2EAB-...  Feature
# 64  http://opencontext.org/projects/fab0532a-2953-...  Feature
# 65  http://opencontext.org/projects/56110B30-3C18-...  Feature
# 66  http://opencontext.org/projects/F905BD53-C843-...  Feature
# 67  http://opencontext.org/projects/7f82f3f3-04d2-...  Feature
# 68  http://opencontext.org/projects/295B5BF4-0F44-...  Feature
# 69  http://opencontext.org/projects/5F2D4172-D823-...  Feature
# 70  http://opencontext.org/projects/F9970276-8636-...  Feature
# 71  http://opencontext.org/projects/HazorZooPRJ000...  Feature
# 72  http://opencontext.org/projects/3FAAA477-5572-...  Feature
# 73  http://opencontext.org/projects/DTrev1PRJ00000...  Feature
# 74  http://opencontext.org/projects/GBHayPRJ000000...  Feature
# 75  http://opencontext.org/projects/8859aa10-c0c4-...  Feature
# 76  http://opencontext.org/projects/PGold1PRJ00000...  Feature
# 77  http://opencontext.org/projects/766d9fd5-2175-...  Feature
#
# [78 rows x 7 columns]

# %% [markdown]
# I don't understand why we get only 78 results and not 109.

# %% [markdown]
# # Studying a specific project

# %% [markdown]
# https://opencontext.org/projects/C5B4F73B-5EF8-4099-590E-B0275EDBA2A7  --> Presidio project
#
# aka https://opencontext.org/projects/12-presidio-of-san-francisco

# %%
projects_df.iloc[0].properties.get('uri')
# Out:
# 'http://opencontext.org/projects/3DE4CD9C-259E-4C14-9B03-8B10454BA66E'

# %%
import json

k = projects_df.apply(lambda row: row.properties.get('uri'), axis=1)
k.to_dict()
# Out:
# {0: 'http://opencontext.org/projects/3DE4CD9C-259E-4C14-9B03-8B10454BA66E',
#  1: 'http://opencontext.org/projects/347286db-b6c6-4fd2-b3bd-b50316b0cb9f',
#  2: 'http://opencontext.org/projects/GHF1PRJ0000000025',
#  3: 'http://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9',
#  4: 'http://opencontext.org/projects/B4345F6A-F926-4062-144E-3FBC175CC7B6',
#  5: 'http://opencontext.org/projects/01D080DF-2F6B-4F59-BCF0-87543AC89574',
#  6: 'http://opencontext.org/projects/8894EEC0-DC96-4304-1EFC-4572FD91717A',
#  7: 'http://opencontext.org/projects/DF043419-F23B-41DA-7E4D-EE52AF22F92F',
#  8: 'http://opencontext.org/projects/BC90D462-6639-4087-8527-6BB9E528E07D',
#  9: 'http://opencontext.org/projects/05F5B702-2967-49B1-FEAA-9B2AA0184513',
#  10: 'http://opencontext.org/projects/731B0670-CE2A-414A-8EF6-9C050A1C60F5',
#  11: 'http://opencontext.org/projects/1B426F7C-99EC-4322-4069-E8DBD927CCF1',
#  12: 'http://opencontext.org/projects/CF179695-1E6A-440F-1DDB-4FEA7B02A5B5',
#  13: 'http://opencontext.org/projects/A5DDBEA2-B3C8-43F9-8151-33343CBDC857',
#  14: 'http://opencontext.org/projects/1816A043-92E2-471D-A23D-AAC58695D0D3',
#  15: 'http://opencontext.org/projects/CDD40C27-62ED-4966-AF3D-E781DD0D4846',
#  16: 'http://opencontext.org/projects/bdc6cb19-e739-404b-8b4f-eeeaae3b8aae',
#  17: 'http://opencontext.org/projects/D297CD29-50CA-4B2C-4A07-498ADF3AF487',
#  18: 'http://opencontext.org/projects/ea62c747-f3ae-4972-8f83-f8aecfcfbaea',
#  19: 'http://opencontext.org/projects/74749949-4FD4-4C3E-C830-5AA75703E08E',
#  20: 'http://opencontext.org/projects/d3bed915-947d-4c1a-8c9a-b7723f03d21a',
#  21: 'http://opencontext.org/projects/10aa84ad-c5de-4e79-89ce-d83b75ed72b5',
#  22: 'http://opencontext.org/projects/CF6E1364-D6EF-4042-B726-82CFB73F7C9D',
#  23: 'http://opencontext.org/projects/64013C33-4039-46C9-609A-A758CE51CA49',
#  24: 'http://opencontext.org/projects/d1c85af4-c870-488a-865b-b3cf784cfc60',
#  25: 'http://opencontext.org/projects/42EAD4DB-BAED-4A58-9B9B-7EC85266D2A9',
#  26: 'http://opencontext.org/projects/497ADEAD-0C2A-4C62-FEEF-9079FB09B1A5',
#  27: 'http://opencontext.org/projects/ABABD13C-A69F-499E-CA7F-5118F3684E4D',
#  28: 'http://opencontext.org/projects/A3CBADB6-6CD4-4099-9FE2-A33757EAB749',
#  29: 'http://opencontext.org/projects/4B16F48E-6F5D-41E0-F568-FCE64BE6D3FA',
#  30: 'http://opencontext.org/projects/3F6DCD13-A476-488E-ED10-47D25513FCB2',
#  31: 'http://opencontext.org/projects/0cea2f4a-84cb-4083-8c66-5191628abe67',
#  32: 'http://opencontext.org/projects/D6B25EC9-2884-4E3C-00E8-0C5A6472FA63',
#  33: 'http://opencontext.org/projects/81204AF8-127C-4686-E9B0-1202C3A47959',
#  34: 'http://opencontext.org/projects/59E7BFBC-2557-4FE4-FC14-284ED10D903D',
#  35: 'http://opencontext.org/projects/F05ACE4F-9B55-48A0-D640-5276B8B899C7',
#  36: 'http://opencontext.org/projects/B1DAC335-4DC6-4A57-622E-75BF28BA598D',
#  37: 'http://opencontext.org/projects/D42FC0EB-61B0-4937-700E-4EFEAB008677',
#  38: 'http://opencontext.org/projects/3',
#  39: 'http://opencontext.org/projects/cbd24bbb-c6fc-44ed-bd67-6f844f120ad5',
#  40: 'http://opencontext.org/projects/4B5721E9-2BB3-423F-5D04-1B948FA65FAB',
#  41: 'http://opencontext.org/projects/B7F85EB6-4BF5-43FA-98E7-FF8FAF1AA452',
#  42: 'http://opencontext.org/projects/81d1157d-28f4-46ff-98dd-94899c1688f8',
#  43: 'http://opencontext.org/projects/8492AEC3-E406-44C6-03CA-2BF280D8F5B0',
#  44: 'http://opencontext.org/projects/d75ef68a-0e23-458c-976d-286d83c13013',
#  45: 'http://opencontext.org/projects/8F947319-3C69-4847-B7A2-09E00ED90B32',
#  46: 'http://opencontext.org/projects/416A274C-CF88-4471-3E31-93DB825E9E4A',
#  47: 'http://opencontext.org/projects/B7047162-6906-4A5E-13C0-B5B86A108510',
#  48: 'http://opencontext.org/projects/0EE6A09E-62E5-45F0-1CB9-F5CDA44F4D9E',
#  49: 'http://opencontext.org/projects/TESTPRJ0000000004',
#  50: 'http://opencontext.org/projects/C5B4F73B-5EF8-4099-590E-B0275EDBA2A7',
#  51: 'http://opencontext.org/projects/766698E3-2E79-4A78-B0BC-245FF435BBBD',
#  52: 'http://opencontext.org/projects/EDDA846F-7225-495E-AB77-7314C256449A',
#  53: 'http://opencontext.org/projects/27e90af3-6bf7-4da1-a1c3-7b2f744e8cf7',
#  54: 'http://opencontext.org/projects/HPeaZooPRJ0000000012',
#  55: 'http://opencontext.org/projects/23696274-1f6d-44ca-9697-36b9d5e3fe5d',
#  56: 'http://opencontext.org/projects/b6de18c6-bba8-4b53-9d9e-3eea4b794268',
#  57: 'http://opencontext.org/projects/2bc1f77d-fe36-41eb-99b9-c0261edb4f18',
#  58: 'http://opencontext.org/projects/a820af0c-ab4d-4518-ba91-ac3bede21c4d',
#  59: 'http://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd',
#  60: 'http://opencontext.org/projects/MHS1PRJ0000000021',
#  61: 'http://opencontext.org/projects/8ae150fc-50f1-4e60-9dd3-df594b02ddd4',
#  62: 'http://opencontext.org/projects/646b7034-07b7-4971-8d89-ebe37dda4cd2',
#  63: 'http://opencontext.org/projects/AF0D2F67-2EAB-4C28-9C61-0F019CBF628E',
#  64: 'http://opencontext.org/projects/fab0532a-2953-4f13-aa97-8a9d7e992dbe',
#  65: 'http://opencontext.org/projects/56110B30-3C18-49F9-BDA9-550FE8E28450',
#  66: 'http://opencontext.org/projects/F905BD53-C843-4349-0A46-48FF32B5F1BE',
#  67: 'http://opencontext.org/projects/7f82f3f3-04d2-47c3-b0a9-21aa28294d25',
#  68: 'http://opencontext.org/projects/295B5BF4-0F44-4698-80CD-7A39CB6F133D',
#  69: 'http://opencontext.org/projects/5F2D4172-D823-4F7F-D3A8-4BD68ED1369D',
#  70: 'http://opencontext.org/projects/F9970276-8636-478D-A3F0-08CC7EFEAD4F',
#  71: 'http://opencontext.org/projects/HazorZooPRJ0000000010',
#  72: 'http://opencontext.org/projects/3FAAA477-5572-4B05-8DC1-CA264FE1FC10',
#  73: 'http://opencontext.org/projects/DTrev1PRJ0000000014',
#  74: 'http://opencontext.org/projects/GBHayPRJ0000000005',
#  75: 'http://opencontext.org/projects/8859aa10-c0c4-42ad-993b-cc9d79800d8e',
#  76: 'http://opencontext.org/projects/PGold1PRJ0000000005',
#  77: 'http://opencontext.org/projects/766d9fd5-2175-41e3-b7c9-7eba6777f1f0'}

# %%
#presidio project is not in that list

projects_df[projects_df.apply(lambda row: row.properties.get('uri'), axis=1) == 'https://opencontext.org/projects/C5B4F73B-5EF8-4099-590E-B0275EDBA2A7']
# Out:
# Empty DataFrame
# Columns: [category, geometry, id, label, properties, rdfs:isDefinedBy, type]
# Index: []

# %%
oc.project('C5B4F73B-5EF8-4099-590E-B0275EDBA2A7')
# Out:
# {'@context': ['https://opencontext.org/contexts/item.json',
#   'http://geojson.org/geojson-ld/geojson-context.jsonld',
#   {}],
#  'bibo:status': [{'id': 'http://opencontext.org/vocabularies/oc-general/edit-level-3',
#    'label': 'Managing editor reviewed',
#    'slug': 'oc-gen-edit-level-3'},
#   {'id': 'http://purl.org/ontology/bibo/status/peerReviewed',
#    'label': 'Peer reviewed',
#    'slug': 'bibo-status-peerreviewed'}],
#  'dc-terms:abstract': "<p>The Presidio of San Francisco is a national park site measuring 1491 acres, administered jointly by the Presidio Trust and the National Park Service. The Presidio was in continuous use as a military post from 1776 to 1994, serving under the flags of Spain, Mexico, and the United States. During the transition from an active Army Post to a National Park, an update to the Presidio\x92s National Historic Landmark designation was undertaken. This effort documented nearly 4000 sites, buildings, structures, and objects as contributing features to the Landmark, and the Presidio was reclassified as a National Historic Landmark District\x97the highest designation. Included were 54 locations of predicted archaeological significance, including forgotten cemeteries, shipwrecks, native shell mounds, coastal fortifications and the cornerstone of the Presidio Trust\x92s Archaeology Program\x97the Spanish Colonial site <em>El Presidio de San Francisco</em>. Due to the Presidio\x92s long continuum of history from colonialism till the Cold War, there is an array of important sites beyond the temporal and spatial boundaries of El Presidio which make this park exceptional as an archaeological resource.</p>  \r\n\r\n<p>The Presidio Archaeology Lab is home to the Archaeology Program of the Presidio Trust. It is the nexus of all archaeological efforts at the Presidio where a lively community engages in the stewardship of the Presidio\x92s rich archaeological heritage. <em>El Presidio de San Francisco</em> is the only one of four Spanish fortifications and twenty-one missions in California located in a National Park. This results in an opportunity to reach and teach a large audience about this irreplaceable resource, the Spanish Colonial episode in our nation\x92s heritage, as well as the methods of archaeology, history, and related sciences. The mission of the Presidio Archaeology Lab is to demonstrate leadership in the field of archaeology and enhance the understanding of our shared cultural heritage.</p>    \r\n\r\n<p>The goals of the Presidio Archaeology Lab are:</p>\r\n<ul>\r\n    <li>To create a compelling destination at the site of <em>El Presidio de San Francisco</em>, one that instills visitors with the imaginative tools necessary to explore a broader range of the American experience.</li>\r\n    <li>To encourage a sense of collective ownership for the past, and this park, by involving diverse members of the public in all our programs and enabling them to make their own connections to this place.</li>\r\n    <li>To preserve the integrity of the archaeological sites, features, and artifacts, which form the foundation of our programs, ensuring that authentic experiences are available to future generations.</li>\r\n</ul>\r\n\r\n<br/>\r\n<p class='subHeader'>Additional Web Resources:</p>\r\n<ul>\r\n    <li><a href='http://www.presidio.gov/history/archaeology/'>Presidio Archaeology Lab Website</a></li> \r\n    <li><a href='http://library.presidio.gov/archive/documents/Levantar-pt1.pdf'>Levantar, The Presidio of San Francisco Archaeological Management Strategy</a> (PDF)</li>\r\n    <li><a href='http://www.presidio.gov/'>Presidio Trust Website</a></li> \r\n</ul>\r\n\r\n<br/>\r\n<p class='subHeader'>Additional Web Resources:</p>\r\n<p>Presidio Archaeology Lab<br/>\r\nPresidio Trust<br/> \r\nPO Box 29052<br/>\r\nSan Francisco, CA 94129 USA<br/>\r\nPhone: (415) 561-ARCH<br/>\r\nFax: (415) 561-5089<br/>\r\narchaeology@presidiotrust.gov<br/> \r\n</p>",
#  'dc-terms:creator': [],
#  'dc-terms:isReferencedBy': [{'id': 'http://opencontext.org/tables/2edc4d5eeffe18944c973b242c555cbe',
#    'label': 'Presidio Chickens',
#    'slug': '12-presidio-chickens'},
#   {'id': 'http://opencontext.org/tables/be34b6fb5f62535d07eae6b6cac3c73e',
#    'label': 'Presidio Building 39 Animal Bones',
#    'slug': '12-presidio-building-39-animal-bones'}],
#  'dc-terms:issued': '2010-01-25',
#  'dc-terms:license': [{'id': 'http://creativecommons.org/licenses/by/4.0/',
#    'label': 'Attribution 4.0',
#    'slug': 'cc-license-by-4-0'}],
#  'dc-terms:modified': '2014-05-19',
#  'dc-terms:spatial': [{'id': 'http://www.geonames.org/5391959',
#    'label': 'San Francisco',
#    'slug': 'geonames-5391959'},
#   {'id': 'http://www.geonames.org/5332921',
#    'label': 'California',
#    'slug': 'geonames-5332921'}],
#  'dc-terms:subject': [{'id': 'http://id.loc.gov/authorities/subjects/sh85006513',
#    'label': 'Historical archaeology',
#    'slug': 'loc-sh-sh85006513'},
#   {'id': 'http://en.wikipedia.org/wiki/History_of_California',
#    'label': 'History of California',
#    'slug': 'wiki-history-of-california'},
#   {'id': 'http://id.loc.gov/authorities/subjects/sh85140642',
#    'label': 'United States. Army--History',
#    'slug': 'loc-sh-sh85140642'},
#   {'id': 'http://id.loc.gov/authorities/subjects/sh99005758',
#    'label': 'Education',
#    'slug': 'loc-sh-sh99005758'}],
#  'dc-terms:title': 'Presidio of San Francisco',
#  'description': 'Ongoing investigations of El Presidio de San Francisco and other archaeological resources at the Presidio of San Francisco',
#  'features': [{'geometry': {'coordinates': [-122.455925, 37.800154],
#     'id': '#geo-geom-1',
#     'type': 'Point'},
#    'id': '#geo-1',
#    'properties': {'href': 'http://opencontext.org/projects/C5B4F73B-5EF8-4099-590E-B0275EDBA2A7',
#     'id': '#geo-props-1',
#     'location-note': 'Location data available with no intentional reduction in precision.',
#     'note': 'Project geographic coverage                         summarized from geospatial data                         describing subjects published                         with this project.',
#     'reference-type': 'specified',
#     'type': 'oc-gen:geo-coverage'},
#    'type': 'Feature'}],
#  'foaf:depiction': [{'dc-terms:hasFormat': 'http://purl.org/NET/mediatypes/image/jpeg',
#    'dcat:size': 366385.0,
#    'id': 'http://artiraq.org/static/opencontext/presidio-of-san-francisco/heros/presidio-bldg39-hero.jpg',
#    'type': 'oc-gen:hero'}],
#  'id': 'http://opencontext.org/projects/C5B4F73B-5EF8-4099-590E-B0275EDBA2A7',
#  'label': 'Presidio of San Francisco',
#  'owl:sameAs': [{'id': 'https://n2t.net/ark:/28722/k21n86s85'},
#   {'id': 'http://opencontext.org/projects/12-presidio-of-san-francisco'}],
#  'slug': '12-presidio-of-san-francisco',
#  'type': 'FeatureCollection',
#  'uuid': 'C5B4F73B-5EF8-4099-590E-B0275EDBA2A7'}

# %% [markdown]
# * Data Records
# * Media

# %%
# this takes a while to get through all 1000+ records 
# limit this to 50

for (i, record) in enumerate(islice(oc.subjects_search('12-presidio-of-san-francisco'),50)):
    print ("\r", i, end="")
# Out:
# https://opencontext.org/subjects-search.json/?proj=12-presidio-of-san-francisco
#  49
